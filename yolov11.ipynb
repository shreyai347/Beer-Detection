# %%
# %pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.4/112.6 GB disk)

# %%
from ultralytics import YOLO
import torch

def main():
    print("CUDA available:", torch.cuda.is_available())
    print("Number of GPUs:", torch.cuda.device_count())
    if torch.cuda.is_available():
        print("Using GPU:", torch.cuda.get_device_name(0))
    else:
        print("Using CPU")

    model = YOLO('yolo11m.pt')

    save_dir = '/content/drive/MyDrive/roboflow/model'

    model.train(
        data='/content/drive/MyDrive/roboflow/data.yaml',
        epochs=100,
        device=0 if torch.cuda.is_available() else 'cpu',
        project=save_dir,
        name='yolo_model',
        save=True
    )

    print("done!")

if __name__ == '__main__':
    main()
# Out:
# CUDA available: True
# Number of GPUs: 1
# Using GPU: Tesla T4
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
import cv2
import os

def load_model(weights_path):
    model = YOLO(weights_path)
    return model

def infer(model, image_paths, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for path in image_paths:
        img = cv2.imread(path)

        if img is None:
            print(f"Failed to load image at {path}")
            continue

        results = model(img)

        for i, result in enumerate(results):
            output_image_path = os.path.join(output_dir, f"output_{os.path.basename(path)}")
            result.save(filename=output_image_path)
            print(f"Saved output image to {output_image_path}")
            result.show()

def main():
    model = load_model('/content/drive/MyDrive/roboflow/model/yolo_model/weights/best.pt')

    image_paths = [
        '/content/drive/MyDrive/beer images /beer-1218742_640.jpg',
        '/content/drive/MyDrive/beer images /beer-199650_640.jpg',
        '/content/drive/MyDrive/beer images /beer-2370783_640.jpg',
        '/content/drive/MyDrive/beer images /beer-422138_640.jpg',
        '/content/drive/MyDrive/beer images /beer-5910451_640.jpg',
        '/content/drive/MyDrive/beer images /beer-820011_640.jpg',
        '/content/drive/MyDrive/beer images /istockphoto-1479800728-612x612.jpg',
        '/content/drive/MyDrive/beer images /istockphoto-927390744-612x612.jpg'
    ]

    output_dir = '/content/drive/MyDrive/beer images /output images '

    infer(model, image_paths, output_dir)

if __name__ == '__main__':
    main()
# Out:
# 0: 640x448 1 beer, 28.7ms
# Speed: 1.8ms preprocess, 28.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
# Saved output image to /content/drive/MyDrive/beer images /output images /output_beer-1218742_640.jpg
# <PIL.Image.Image image mode=RGB size=427x640>
# 0: 448x640 1 beer, 32.3ms
# Speed: 1.5ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Saved output image to /content/drive/MyDrive/beer images /output images /output_beer-199650_640.jpg
# <PIL.Image.Image image mode=RGB size=640x427>
# 0: 384x640 5 beers, 25.2ms
# Speed: 1.5ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Saved output image to /content/drive/MyDrive/beer images /output images /output_beer-2370783_640.jpg
# <PIL.Image.Image image mode=RGB size=640x360>
# 0: 640x448 1 beer, 28.8ms
# Speed: 1.8ms preprocess, 28.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 448)
# ...
